# %% [markdown]
# # Preprocessing and Aggregating data
# - mainly Time series data
# - sorting data

# %% [markdown]
# ### Sorting the dataframe

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'roll_no' : [102,101,104,103,105],
    'name' : ['Aravind','Rahul','Praveen','Priya','Rahul'],
    'grade' : ['A','B','C','A','C'],
    'marks' : [22,15,10,23,9]
})

# %%
df
# Out:
#    roll_no     name grade  marks
# 0      102  Aravind     A     22
# 1      101    Rahul     B     15
# 2      104  Praveen     C     10
# 3      103    Priya     A     23
# 4      105    Rahul     C      9

# %% [markdown]
# ### sort the df by grades

# %%
df.sort_values(by = ['grade'])
# Out:
#    roll_no     name grade  marks
# 0      102  Aravind     A     22
# 3      103    Priya     A     23
# 1      101    Rahul     B     15
# 2      104  Praveen     C     10
# 4      105    Rahul     C      9

# %%
df.sort_values(by = ['roll_no'])
# Out:
#    roll_no     name grade  marks
# 1      101    Rahul     B     15
# 0      102  Aravind     A     22
# 3      103    Priya     A     23
# 2      104  Praveen     C     10
# 4      105    Rahul     C      9

# %% [markdown]
# ##### now i need grades from 'A' to 'c' and marks highest to lowest

# %%
df.sort_values(by = ['grade', 'marks'], ascending=[True, False])
# Out:
#    roll_no     name grade  marks
# 3      103    Priya     A     23
# 0      102  Aravind     A     22
# 1      101    Rahul     B     15
# 2      104  Praveen     C     10
# 4      105    Rahul     C      9

# %%
df
# Out:
#    roll_no     name grade  marks
# 0      102  Aravind     A     22
# 1      101    Rahul     B     15
# 2      104  Praveen     C     10
# 3      103    Priya     A     23
# 4      105    Rahul     C      9

# %% [markdown]
# #### Note
# - even though we have sorted the df based on our criteria the original df is not changed.... that is where inplace comes into action,

# %%
df.sort_values(by = ['grade', 'marks'], ascending=[True, False], inplace = True)

# %%
df
# Out:
#    roll_no     name grade  marks
# 3      103    Priya     A     23
# 0      102  Aravind     A     22
# 1      101    Rahul     B     15
# 2      104  Praveen     C     10
# 4      105    Rahul     C      9

# %%
df.reset_index()
# Out:
#    index  roll_no     name grade  marks
# 0      3      103    Priya     A     23
# 1      0      102  Aravind     A     22
# 2      1      101    Rahul     B     15
# 3      2      104  Praveen     C     10
# 4      4      105    Rahul     C      9

# %%
# we can see 2 index so we have to handle this

df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#    roll_no     name grade  marks
# 0      103    Priya     A     23
# 1      102  Aravind     A     22
# 2      101    Rahul     B     15
# 3      104  Praveen     C     10
# 4      105    Rahul     C      9

# %% [markdown]
# ## Working with multiple dataframe

# %%
df1 = pd.DataFrame({
    'roll_no' : [106,108,110,107,109],
    'name' : ['Aravindhan','Rahul Shing','Prakash','Pragya','Rajesh'],
    'grade' : ['A','B','C','A','C'],
    'marks' : [22,15,10,23,9]
})

# %%
df2 = pd.DataFrame({
    'roll_no' : [111,114,112,115,113],
    'name' : ['Ashwin','Girish','Jenish','Arun','Naren'],
    'grade' : ['A','B','C','A','C'],
    'marks' : [22,15,10,23,9]
})

# %%
df.shape, df1.shape, df2.shape
# Out:
# ((5, 4), (5, 4), (5, 4))

# %%
df2.head()
# Out:
#    roll_no    name grade  marks
# 0      111  Ashwin     A     22
# 1      114  Girish     B     15
# 2      112  Jenish     C     10
# 3      115    Arun     A     23
# 4      113   Naren     C      9

# %%
all_df = [df,df1,df2]

all_dataframe = pd.concat(all_df,axis = 0)

# %%
all_dataframe
# Out:
#    roll_no         name grade  marks
# 0      103        Priya     A     23
# 1      102      Aravind     A     22
# 2      101        Rahul     B     15
# 3      104      Praveen     C     10
# 4      105        Rahul     C      9
# 0      106   Aravindhan     A     22
# 1      108  Rahul Shing     B     15
# 2      110      Prakash     C     10
# 3      107       Pragya     A     23
# 4      109       Rajesh     C      9
# 0      111       Ashwin     A     22
# 1      114       Girish     B     15
# 2      112       Jenish     C     10
# 3      115         Arun     A     23
# 4      113        Naren     C      9

# %%
all_dataframe.reset_index(inplace = True, drop = True)

# %%
all_dataframe
# Out:
#     roll_no         name grade  marks
# 0       103        Priya     A     23
# 1       102      Aravind     A     22
# 2       101        Rahul     B     15
# 3       104      Praveen     C     10
# 4       105        Rahul     C      9
# 5       106   Aravindhan     A     22
# 6       108  Rahul Shing     B     15
# 7       110      Prakash     C     10
# 8       107       Pragya     A     23
# 9       109       Rajesh     C      9
# 10      111       Ashwin     A     22
# 11      114       Girish     B     15
# 12      112       Jenish     C     10
# 13      115         Arun     A     23
# 14      113        Naren     C      9

# %%
all_dataframe.shape
# Out:
# (15, 4)

# %% [markdown]
# ## Adding another row to dataframe

# %%
phone_no = pd.DataFrame({'phone_no':[123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,123456789,]})

# %%
phone_no
# Out:
#      phone_no
# 0   123456789
# 1   123456789
# 2   123456789
# 3   123456789
# 4   123456789
# 5   123456789
# 6   123456789
# 7   123456789
# 8   123456789
# 9   123456789
# 10  123456789
# 11  123456789
# 12  123456789
# 13  123456789
# 14  123456789

# %%
all_dataframe = pd.concat([all_dataframe, phone_no], axis = 1)

# %%
all_dataframe
# Out:
#     roll_no         name grade  marks   phone_no
# 0       103        Priya     A     23  123456789
# 1       102      Aravind     A     22  123456789
# 2       101        Rahul     B     15  123456789
# 3       104      Praveen     C     10  123456789
# 4       105        Rahul     C      9  123456789
# 5       106   Aravindhan     A     22  123456789
# 6       108  Rahul Shing     B     15  123456789
# 7       110      Prakash     C     10  123456789
# 8       107       Pragya     A     23  123456789
# 9       109       Rajesh     C      9  123456789
# 10      111       Ashwin     A     22  123456789
# 11      114       Girish     B     15  123456789
# 12      112       Jenish     C     10  123456789
# 13      115         Arun     A     23  123456789
# 14      113        Naren     C      9  123456789

# %%
all_dataframe.isna().sum()
# Out:
# roll_no     0
# name        0
# grade       0
# marks       0
# phone_no    0
# dtype: int64
